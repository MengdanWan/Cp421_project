# %% [markdown]
# # CP421 Project (Recommendation System)
# #### *name*
# #### *name*
# #### *name*

# %%
import pandas as pd

rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('ml-latest-small/ml-latest-small/ratings.csv', skiprows=1, sep=',', header=None, names=rnames)

ratings[:]
# Out:
#         user_id  movie_id  rating   timestamp
# 0             1         1     4.0   964982703
# 1             1         3     4.0   964981247
# 2             1         6     4.0   964982224
# 3             1        47     5.0   964983815
# 4             1        50     5.0   964982931
# ...         ...       ...     ...         ...
# 100831      610    166534     4.0  1493848402
# 100832      610    168248     5.0  1493850091
# 100833      610    168250     5.0  1494273047
# 100834      610    168252     5.0  1493846352
# 100835      610    170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_csv('ml-latest-small/ml-latest-small/movies.csv', skiprows=1, sep=',', header=None, names=mnames,)

movies
# Out:
#       movie_id                                      title  \
# 0            1                           Toy Story (1995)
# 1            2                             Jumanji (1995)
# 2            3                    Grumpier Old Men (1995)
# 3            4                   Waiting to Exhale (1995)
# 4            5         Father of the Bride Part II (1995)
# ...        ...                                        ...
# 9737    193581  Black Butler: Book of the Atlantic (2017)
# 9738    193583               No Game No Life: Zero (2017)
# 9739    193585                               Flint (2017)
# 9740    193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741    193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %% [markdown]
# ##### Merge ratings and movies

# %%
data = pd.merge(ratings, movies)
data
# Out:
#         user_id  movie_id  rating   timestamp  \
# 0             1         1     4.0   964982703
# 1             5         1     4.0   847434962
# 2             7         1     4.5  1106635946
# 3            15         1     2.5  1510577970
# 4            17         1     4.5  1305696483
# ...         ...       ...     ...         ...
# 100831      610    160341     2.5  1479545749
# 100832      610    160527     4.5  1479544998
# 100833      610    160836     3.0  1493844794
# 100834      610    163937     3.5  1493848789
# 100835      610    163981     3.5  1493850155
#
#                                    title  \
# 0                       Toy Story (1995)
# 1                       Toy Story (1995)
# 2                       Toy Story (1995)
# 3                       Toy Story (1995)
# 4                       Toy Story (1995)
# ...                                  ...
# 100831                  Bloodmoon (1997)
# 100832  Sympathy for the Underdog (1971)
# 100833                     Hazard (2005)
# 100834                Blair Witch (2016)
# 100835                         31 (2016)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# 2       Adventure|Animation|Children|Comedy|Fantasy
# 3       Adventure|Animation|Children|Comedy|Fantasy
# 4       Adventure|Animation|Children|Comedy|Fantasy
# ...                                             ...
# 100831                              Action|Thriller
# 100832                           Action|Crime|Drama
# 100833                        Action|Drama|Thriller
# 100834                              Horror|Thriller
# 100835                                       Horror
#
# [100836 rows x 6 columns]

# %% [markdown]
# ##### Random choose data for training and rest for test

# %%
data_copy = data.copy()
train_set = data_copy.sample(frac=0.001) #random choose sample
test_set = data_copy.drop(train_set.index)

train_set[:]
# Out:
#        user_id  movie_id  rating   timestamp  \
# 82682       66      4158     4.0  1113190556
# 77533      140      1615     3.0   949666912
# 28639      132       141     3.5  1159428730
# 86450      111      8814     3.0  1516152451
# 53177      186      5008     5.0  1031073408
# ...        ...       ...     ...         ...
# 86862       89    131098     5.0  1520409448
# 48287      610    134130     3.5  1479543002
# 10010       88      1625     3.5  1331421490
# 44119      608      1918     3.0  1117504702
# 62462      424      2710     4.5  1457902048
#
#                                     title                        genres
# 82682                   Monkeybone (2001)      Animation|Comedy|Fantasy
# 77533                    Edge, The (1997)               Adventure|Drama
# 28639                Birdcage, The (1996)                        Comedy
# 86450             Without a Paddle (2004)                        Comedy
# 53177  Witness for the Prosecution (1957)        Drama|Mystery|Thriller
# ...                                   ...                           ...
# 86862                 Saving Santa (2013)     Animation|Children|Comedy
# 48287                  The Martian (2015)        Adventure|Drama|Sci-Fi
# 10010                    Game, The (1997)        Drama|Mystery|Thriller
# 44119              Lethal Weapon 4 (1998)  Action|Comedy|Crime|Thriller
# 62462     Blair Witch Project, The (1999)         Drama|Horror|Thriller
#
# [101 rows x 6 columns]

# %% [markdown]
# ##### This is the test set

# %%
test_set[:]
# Out:
#         user_id  movie_id  rating   timestamp  \
# 0             1         1     4.0   964982703
# 1             5         1     4.0   847434962
# 2             7         1     4.5  1106635946
# 3            15         1     2.5  1510577970
# 4            17         1     4.5  1305696483
# ...         ...       ...     ...         ...
# 100831      610    160341     2.5  1479545749
# 100832      610    160527     4.5  1479544998
# 100833      610    160836     3.0  1493844794
# 100834      610    163937     3.5  1493848789
# 100835      610    163981     3.5  1493850155
#
#                                    title  \
# 0                       Toy Story (1995)
# 1                       Toy Story (1995)
# 2                       Toy Story (1995)
# 3                       Toy Story (1995)
# 4                       Toy Story (1995)
# ...                                  ...
# 100831                  Bloodmoon (1997)
# 100832  Sympathy for the Underdog (1971)
# 100833                     Hazard (2005)
# 100834                Blair Witch (2016)
# 100835                         31 (2016)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# 2       Adventure|Animation|Children|Comedy|Fantasy
# 3       Adventure|Animation|Children|Comedy|Fantasy
# 4       Adventure|Animation|Children|Comedy|Fantasy
# ...                                             ...
# 100831                              Action|Thriller
# 100832                           Action|Crime|Drama
# 100833                        Action|Drama|Thriller
# 100834                              Horror|Thriller
# 100835                                       Horror
#
# [100735 rows x 6 columns]

# %% [markdown]
# ##### Create pivot table for training set and convert it to numpy array

# %%
train_table = pd.pivot_table(train_set, values='rating', index='user_id', columns='title')
train_table
# Out:
# title    127 Hours (2010)  40-Year-Old Virgin, The (2005)  \
# user_id
# 18                    NaN                             NaN
# 19                    NaN                             NaN
# 28                    NaN                             NaN
# 34                    NaN                             NaN
# 47                    NaN                             NaN
# ...                   ...                             ...
# 587                   NaN                             NaN
# 597                   NaN                             NaN
# 599                   NaN                             NaN
# 608                   NaN                             NaN
# 610                   NaN                             NaN
#
# title    Alien³ (a.k.a. Alien 3) (1992)  American Gangster (2007)  \
# user_id
# 18                                  NaN                       NaN
# 19                                  NaN                       NaN
# 28                                  NaN                       NaN
# 34                                  NaN                       NaN
# 47                                  NaN                       NaN
# ...                                 ...                       ...
# 587                                 NaN                       NaN
# 597                                 NaN                       NaN
# 599                                 NaN                       NaN
# 608                                 NaN                       NaN
# 610                                 NaN                       NaN
#
# title    American History X (1998)  Apollo 13 (1995)  \
# user_id
# 18                             4.0               NaN
# 19                             NaN               NaN
# 28                             NaN               NaN
# 34                             NaN               NaN
# 47                             NaN               NaN
# ...                            ...               ...
# 587                            NaN               NaN
# 597                            NaN               NaN
# 599                            NaN               NaN
# 608                            NaN               NaN
# 610                            NaN               NaN
#
# title    Batman: The Dark Knight Returns, Part 1 (2012)  \
# user_id
# 18                                                  NaN
# 19                                                  NaN
# 28                                                  NaN
# 34                                                  NaN
# 47                                                  NaN
# ...                                                 ...
# 587                                                 NaN
# 597                                                 NaN
# 599                                                 NaN
# 608                                                 NaN
# 610                                                 NaN
#
# title    Being John Malkovich (1999)  \
# user_id
# 18                               NaN
# 19                               NaN
# 28                               NaN
# 34                               NaN
# 47                               NaN
# ...                              ...
# 587                              NaN
# 597                              NaN
# 599                              NaN
# 608                              NaN
# 610                              NaN
#
# title    Bird People in China, The (Chûgoku no chôjin) (1998)  \
# user_id
# 18                                                     NaN
# 19                                                     NaN
# 28                                                     NaN
# 34                                                     NaN
# 47                                                     NaN
# ...                                                    ...
# 587                                                    NaN
# 597                                                    NaN
# 599                                                    NaN
# 608                                                    NaN
# 610                                                    4.0
#
# title    Birdcage, The (1996)  ...  The Martian (2015)  Tigerland (2000)  \
# user_id                        ...
# 18                        NaN  ...                 NaN               NaN
# 19                        NaN  ...                 NaN               NaN
# 28                        NaN  ...                 NaN               NaN
# 34                        NaN  ...                 NaN               NaN
# 47                        NaN  ...                 NaN               NaN
# ...                       ...  ...                 ...               ...
# 587                       NaN  ...                 NaN               NaN
# 597                       NaN  ...                 NaN               NaN
# 599                       NaN  ...                 NaN               NaN
# 608                       NaN  ...                 NaN               NaN
# 610                       NaN  ...                 3.5               NaN
#
# title    Toy Story 2 (1999)  Tucker & Dale vs Evil (2010)  \
# user_id
# 18                      NaN                           NaN
# 19                      NaN                           NaN
# 28                      NaN                           NaN
# 34                      NaN                           NaN
# 47                      NaN                           NaN
# ...                     ...                           ...
# 587                     NaN                           NaN
# 597                     NaN                           NaN
# 599                     NaN                           NaN
# 608                     NaN                           NaN
# 610                     NaN                           NaN
#
# title    Under Siege 2: Dark Territory (1995)  We Own the Night (2007)  \
# user_id
# 18                                        NaN                      NaN
# 19                                        NaN                      NaN
# 28                                        NaN                      NaN
# 34                                        NaN                      NaN
# 47                                        NaN                      NaN
# ...                                       ...                      ...
# 587                                       NaN                      NaN
# 597                                       NaN                      NaN
# 599                                       NaN                      NaN
# 608                                       NaN                      NaN
# 610                                       NaN                      NaN
#
# title    Weird Science (1985)  When in Rome (2010)  Without a Paddle (2004)  \
# user_id
# 18                        NaN                  NaN                      NaN
# 19                        NaN                  NaN                      NaN
# 28                        NaN                  NaN                      NaN
# 34                        NaN                  NaN                      NaN
# 47                        NaN                  NaN                      NaN
# ...                       ...                  ...                      ...
# 587                       NaN                  NaN                      NaN
# 597                       NaN                  NaN                      NaN
# 599                       NaN                  NaN                      NaN
# 608                       NaN                  NaN                      NaN
# 610                       NaN                  NaN                      NaN
#
# title    Witness for the Prosecution (1957)
# user_id
# 18                                      NaN
# 19                                      NaN
# 28                                      NaN
# 34                                      NaN
# 47                                      NaN
# ...                                     ...
# 587                                     NaN
# 597                                     NaN
# 599                                     NaN
# 608                                     NaN
# 610                                     NaN
#
# [75 rows x 100 columns]

# %%
movies = []
for col in train_table.columns:
    movies.append(col)
    #print(col)
#print(movieId)
#print(len(movieId))

train_array = train_table.to_numpy()
print(train_array)
print(len(train_array))
print(len(train_array[0]))

#print(train_array.dtype)
# Out:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# 75
# 100

# %% [markdown]
# ##### The function for covert rating data to binary data.
# ##### If the rate above the user's average rate equal to 1, else set to 'nan' (we only need positive rate)

# %%
import numpy as np
def ratingToBinary(array):
    userNo = len(array)
    mean = np.nanmean(array, axis = 1)
    #print(mean)
    for user in range(0, userNo):
        movieNo = len(array[user])
        for movie in range(0, movieNo):
            if not np.isnan(array[user][movie]):
                if array[user][movie] >= mean[user]:
                    array[user][movie] = 1
                else:
                    array[user][movie] = np.nan
     #   print(array[user])
                    
#ratingToBinary(train_array)

# %%
print(train_array)
ratingToBinary(train_array)
print(train_array)
# Out:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %% [markdown]
# ##### Replace 1 with movie name

# %%
train = []
for user in range(0, len(train_array)):
    u = []
    for movie in range(0, len(train_array[user])):
        if train_array[user][movie] == 1.0:
            u.append(movies[movie])
        else:
            u.append(str(train_array[user][movie]))
    train.append(u)
# Out:
# [['nan', 'nan', 'nan', 'nan', 'American History X (1998)', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'Nutty Professor, The (1996)', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'Poison Ivy: New Seduction (1997)', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'Shooting Dogs (a.k.a. Beyond the Gates) (2005)', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'The Gift (2015)', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan' ...

# %% [markdown]
# ##### Need install apyori package to run the code below

# %%
#!pip install apyori

# %% [markdown]
# #### Using apriori algorithm get rules

# %%
from apyori import apriori
minSup = 0.001
minConf = 0.2
minLift = 1.1
minLen = 2

rules = apriori(train, min_support = minSup, min_confidence = minConf, min_lift = minLift, min_length = minLen)
print(rules)
res = list(rules)
print(len(res))
print(res[0])
# Out:
# <generator object apriori at 0x000001C131A92B48>
# 18
# RelationRecord(items=frozenset({'Femme Nikita, La (Nikita) (1990)', 'Shakespeare in Love (1998)'}), support=0.013333333333333334, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Femme Nikita, La (Nikita) (1990)'}), items_add=frozenset({'Shakespeare in Love (1998)'}), confidence=1.0, lift=75.0), OrderedStatistic(items_base=frozenset({'Shakespeare in Love (1998)'}), items_add=frozenset({'Femme Nikita, La (Nikita) (1990)'}), confidence=1.0, lift=75.0)])
